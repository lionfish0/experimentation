# %%
# !pwd
# Out:
# /home/mike/Documents/Research/bee/photos_March12

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import glob

# %%
# Out:
# 1584007985.1307611

# %%
lasttt
# Out:
# 1584007985.1307611

# %%
lasttt=np.inf
print("Datetime stamp, Tried to fire, Really fired")
for f in sorted(glob.glob('*.np')):

    d = np.load(f,allow_pickle=True)
    if d[2]['triggertime']>lasttt+1:
        print(" ")
    #print(">>>> ",end="")
        
    
    try:
        meandiff = d[2]['photoaverages']['this']-d[2]['photoaverages']['last']
        flashfired = (meandiff>2)
    except KeyError:
        flashfired = None
    print("%30s %6s %6s"  % (d[2]['triggertimestring'],str(d[2]['flash']),str(flashfired)))
    lasttt = d[2]['triggertime']
# Out:
# Datetime stamp, Tried to fire, Really fired
#       20200312_09:38:09.107248  False   None
#       20200312_09:38:09.173514   True   True
#       20200312_09:38:09.217567  False  False
#
#       20200312_09:43:19.261074  False   None
#       20200312_09:43:19.306827   True   True
#       20200312_09:43:19.350487  False  False
#
#       20200312_09:43:27.281830  False   None
#       20200312_09:43:27.327382   True   True
#       20200312_09:43:27.371218  False  False
#
#       20200312_09:43:35.302769  False   None
#       20200312_09:43:35.348236   True   True
#       20200312_09:43:35.391924  False  False
#
#       20200312_09:43:43.322572  False   None
#       20200312_09:43:43.371336   True   True
#       20200312_09:43:43.417109  False  False
#
#       20200312_09:43:51.349703  False   None
#       20200312_09:43:51.399491   True   None
#       20200312_09:43:51.444327  False  False
#
#       20200312_09:43:59.376963  False   None
#       20200312_09:43:59.422275   True   True
# ...

# %%
d
# Out:
# [0, array([[ 21,  20,  17, ...,  16,  17,  18],
#         [ 21,  23,  18, ...,  16,  20,  19],
#         [ 20,  24,  22, ...,  16,  19,  17],
#         ...,
#         [230, 232, 233, ...,  88,  87,  86],
#         [235, 239, 240, ...,  88,  89,  86],
#         [238, 240, 238, ...,  86,  87,  88]], dtype=uint8), {'triggertimestring': '20200312_09:38:09.107248',
#   'triggertime': 1584005889.107171,
#   'index': 0,
#   'flash': False,
#   'direction': 0,
#   'flashselection': [0]}]
